# %% [markdown]
# ### **Q1-Create a variable called city and store your city's name in it. Then print it.**

# %%
city='Rawalpindi'
print(city)
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/Memuna Javed/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### **Q2(i)-What do you think happens if you write 20 = age instead of age = 20? Try it and see what Python says.**
#
#     An error is expected as in programming, as always 'the value of RHS is assigned to the LHS', and the vice versa is not true.
#     age=20 in python is equalent to age:=20 in maths.
#     And the age==20 is equivalent to age=20 in maths.
#
# ### **Q2(ii)-What do you think happens if you write age = age = 20 instead of age = 20? Try it and see what Python says.**
#
#     age=age=20 is equivalent to age=20 and age=age similar to x=y=z=8 (which is equivalent to z=8 and y=z and x=y).
#     Always the value of the RHS is assigned to the LHS.

# %% [markdown]
# ### **Q3-Create two variables, score and level, give them values, and print both in one line using print().**

# %%
print(f"The score for level {level} is {score}!")

# %% [markdown]
# <center> OR </center>

# %%
print(score,level)

# %% [markdown]
# <center> OR </center>

# %%
print("The score for level",level,"is",score,"!")
