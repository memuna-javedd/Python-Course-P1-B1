# %% [markdown]
# ### **Q1-Convert the string "100" into an integer and add 50 to it.**

# %%
var="100"
var=int(100)
var+=50
print(f'The value of var is {var} and its data type is {type(var)}')
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/Memuna Javed/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### **Q2-What happens if you try int("hello")? Run it and read the error message carefully why does it fail?**

# %% [markdown]
# It would give an error because "hello" cannot be converted into an integar.

# %%
var2="hello"
var2=int("hello")  # error expected

# %% [markdown]
# ### **Q3-Convert 3.99 into an integer using int(). What happens to the decimal part?**

# %%
var3=3.99
var3=int(var3)
print(f'The value of var3 is {var3}')

# %% [markdown]
# The decimal part is simply truncated.
