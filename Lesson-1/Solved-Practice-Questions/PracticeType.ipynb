# %% [markdown]
# ### **Q1-Use type() to check the type of a variable you created earlier in this lesson.**

# %%
city='Rawalpindi'
score=20
isHappy=True
gpa=3.92

print(type(city))
print(type(score))
print(type(isHappy))
print(type(gpa))

# %% [markdown]
# ### **Q2-What type do you think 5 + 2.0 results in? Try it in Python and check if you were right.**

# %% [markdown]
# I think it should result in flaot type due to implicit type casting.

# %%
print(f'The type of 5 + 2.0 is {type(5+2.0)}')

# %% [markdown]
# ### **Q3-Guess before running: what does type("5") return int or str? Why might Python treat it that way even though it looks like a number?**

# %% [markdown]
# It would return str because in python, any data that is written in sungle or double quotes is treated as a string type.

# %%
print(f'The data type of "5" is {type("5")}')
