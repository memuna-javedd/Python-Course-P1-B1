# %% [markdown]
# ### **Q1-Which of these are valid variable names? 2total, total_2, total-2, _total**

# %% [markdown]
# total_2
# _total

# %% [markdown]
# ### **Q2-Rewrite "user name" as a valid Python variable name.**

# %% [markdown]
# user_name
# userName

# %% [markdown]
# ### **Q3-Create two variables, score and Score, give them different values, and print both. What does this tell you about case sensitivity?**

# %%
score=20
Score=2000

print(f"score={score}\nScore={Score}")
# Out:
# Running cells with 'Python 3.13.14' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '"c:/Users/Memuna Javed/AppData/Local/Microsoft/WindowsApps/python3.13.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# It proves that python is a case-sensitive language.
