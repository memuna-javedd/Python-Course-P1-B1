# %% [markdown]
# ### **Q1-Identify the data type of each: 5, "Pakistan", 3.14, False**

# %% [markdown]
# |Value|Data Type|
# |-|-|
# |5|int|
# |"Pakistan"|str|
# |3.14|float|
# |False|bool|

# %% [markdown]
# ### **Q2-Create one variable of each type: an int, a float, a str, and a bool.**

# %%
salary=58000
height=5.4
color='yellow'
isHappy=True

# %% [markdown]
# ### **Q3-What data type would you use to store: your CNIC number, your GPA, and whether you're logged in?**

# %% [markdown]
# |Data|Type|
# |-|-|
# |CNIC number|str|
# |GPA|float|
# |logged in|bool|
